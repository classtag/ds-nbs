# %%
import warnings
warnings.simplefilter('ignore')

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
import plotnine as pln
# %matplotlib inline
sns.set_style('darkgrid')

# %%
pd.options.display.max_columns = None

# %%
movies = pd.read_csv('/home/duoan/work/input/tmdb/tmdb-movies.csv', index_col='id')

# %%
movies.head(5)
# Out:
#           imdb_id  popularity     budget     revenue  \
# id
# 135397  tt0369610   32.985763  150000000  1513528810
# 76341   tt1392190   28.419936  150000000   378436354
# 262500  tt2908446   13.112507  110000000   295238201
# 140607  tt2488496   11.173104  200000000  2068178225
# 168259  tt2820852    9.335014  190000000  1506249360
#
#                       original_title  \
# id
# 135397                Jurassic World
# 76341             Mad Max: Fury Road
# 262500                     Insurgent
# 140607  Star Wars: The Force Awakens
# 168259                     Furious 7
#
#                                                      cast  \
# id
# 135397  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# 76341   Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...
# 262500  Shailene Woodley|Theo James|Kate Winslet|Ansel...
# 140607  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...
# 168259  Vin Diesel|Paul Walker|Jason Statham|Michelle ...
#
# ...

# %% [markdown]
# ## 数据校验

# %%
movies.shape
# Out:
# (10866, 20)

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10866 entries, 135397 to 22293
# Data columns (total 20 columns):
# imdb_id                 10856 non-null object
# popularity              10866 non-null float64
# budget                  10866 non-null int64
# revenue                 10866 non-null int64
# original_title          10866 non-null object
# cast                    10790 non-null object
# homepage                2936 non-null object
# director                10822 non-null object
# tagline                 8042 non-null object
# keywords                9373 non-null object
# overview                10862 non-null object
# runtime                 10866 non-null int64
# genres                  10843 non-null object
# production_companies    9836 non-null object
# release_date            10866 non-null object
# vote_count              10866 non-null int64
# vote_average            10866 non-null float64
# release_year            10866 non-null int64
# ...

# %%
np.sum(movies.isna())
# Out:
# imdb_id                   10
# popularity                 0
# budget                     0
# revenue                    0
# original_title             0
# cast                      76
# homepage                7930
# director                  44
# tagline                 2824
# keywords                1493
# overview                   4
# runtime                    0
# genres                    23
# production_companies    1030
# release_date               0
# vote_count                 0
# vote_average               0
# release_year               0
# budget_adj                 0
# revenue_adj                0
# dtype: int64

# %%
np.sum(movies.isna(), axis=1)
# Out:
# id
# 135397    0
# 76341     0
# 262500    0
# 140607    0
# 168259    0
# 281957    0
# 87101     0
# 286217    0
# 211672    0
# 150540    0
# 206647    0
# 76757     0
# 264660    0
# 257344    0
# 99861     0
# 273248    0
# 260346    0
# 102899    0
# 150689    1
# 131634    0
# 158852    0
# 307081    1
# 254128    0
# 216015    0
# 318846    0
# 177677    0
# 214756    1
# 207703    0
# 314365    0
# 294254    0
#          ..
# 38720     1
# 19728     1
# 22383     1
# 13353     1
# 34388     2
# 42701     1
# 36540     4
# 29710     1
# 23728     1
# 5065      1
# 17102     1
# 28763     1
# 2161      1
# 28270     1
# 26268     1
# 15347     1
# 37301     1
# 15598     2
# 31602     1
# 13343     1
# 20277     1
# 5921      1
# 31918     1
# 20620     2
# 5060      1
# 21        2
# 20379     1
# 39768     2
# 21449     1
# 22293     1
# Length: 10866, dtype: int64

# %% [markdown]
# # 每年最受欢迎的电影类别是哪些？票房高的电影有哪些特点？

# %% [markdown]
# ## 单变量分析

# %%
movies.popularity.describe(percentiles=[.3, .5, .98])
# Out:
# count    10866.000000
# mean         0.646441
# std          1.000185
# min          0.000065
# 30%          0.239465
# 50%          0.383856
# 98%          3.203822
# max         32.985763
# Name: popularity, dtype: float64

# %%
plt.figure(figsize=(12,4))
_ = sns.boxplot(movies.popularity)

# %%
plt.figure(figsize=(12,4))
_ = sns.distplot(movies.popularity, bins=66)

# %%
pop_movies = movies[movies.popularity>1.350653]

# %%
len(pop_movies)
# Out:
# 1087

# %%
stats_yearly_popularity = movies.groupby('release_year')['popularity'].describe(percentiles=[.3, .5, .98])
stats_yearly_popularity
# Out:
#               count      mean       std       min       30%       50%  \
# release_year
# 1960           32.0  0.458932  0.541833  0.055821  0.204029  0.268273
# 1961           31.0  0.422827  0.526517  0.027527  0.196467  0.265092
# 1962           32.0  0.454783  0.555945  0.038819  0.220850  0.299075
# 1963           34.0  0.502706  0.551040  0.045417  0.197741  0.249940
# 1964           42.0  0.412428  0.620196  0.008990  0.154576  0.194472
# 1965           35.0  0.342587  0.400366  0.004770  0.147155  0.201703
# 1966           46.0  0.304112  0.239278  0.034555  0.157719  0.245917
# 1967           40.0  0.471154  0.593532  0.034181  0.159539  0.240558
# 1968           39.0  0.484202  0.552789  0.005265  0.190508  0.323826
# 1969           31.0  0.422778  0.379827  0.002757  0.224638  0.337430
# 1970           41.0  0.341700  0.301852  0.020760  0.209070  0.284436
# 1971           55.0  0.448112  0.545079  0.000188  0.179318  0.306073
# ...

# %%
axes = stats_yearly_popularity.plot.line(subplots=True, figsize=(12,24))

# %%
movies.popularity.map(lambda x: int(x)).value_counts().sort_index()
# Out:
# 0     9110
# 1     1189
# 2      311
# 3      119
# 4       52
# 5       31
# 6       20
# 7        9
# 8       10
# 9        4
# 10       2
# 11       2
# 12       2
# 13       1
# 14       1
# 24       1
# 28       1
# 32       1
# Name: popularity, dtype: int64

# %%
_ = sns.distplot(movies[movies['popularity']<].popularity, bins=50)

# %%
_ = sns.distplot(movies.budget, bins=20)

# %%
plt.figure(figsize=(12, 8))
_ = sns.boxplot(movies[movies.budget>1]['budget'])

# %%
np.log1p(movies.revenue).describe()

# %%
np.log1p(movies.revenue).describe()
# Out:
# count    10866.000000
# mean         7.472882
# std          8.507716
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%         16.993564
# max         21.746258
# Name: revenue, dtype: float64

# %%
np.log1p(movies.revenue).plot.hist(bins=100)

# %%
_ = sns.distplot(np.log1p(movies[movies['revenue']>0]['revenue']), bins=50)

# %%
movies.release_year.value_counts().sort_index()
# Out:
# 1960     32
# 1961     31
# 1962     32
# 1963     34
# 1964     42
# 1965     35
# 1966     46
# 1967     40
# 1968     39
# 1969     31
# 1970     41
# 1971     55
# 1972     40
# 1973     55
# 1974     47
# 1975     44
# 1976     47
# 1977     57
# 1978     65
# 1979     57
# 1980     78
# 1981     82
# 1982     81
# 1983     80
# 1984    105
# 1985    109
# 1986    121
# 1987    125
# 1988    145
# 1989    137
# 1990    132
# 1991    133
# 1992    133
# 1993    178
# 1994    184
# 1995    175
# 1996    204
# 1997    192
# 1998    210
# 1999    224
# 2000    227
# 2001    242
# 2002    266
# 2003    281
# 2004    307
# 2005    364
# 2006    408
# 2007    438
# 2008    496
# 2009    533
# 2010    490
# 2011    540
# 2012    588
# 2013    659
# 2014    700
# 2015    629
# Name: release_year, dtype: int64

# %%
plt.figure(figsize=(12, 6))
_ = movies.release_year.value_counts().plot.bar(color='mediumvioletred')
plt.xticks(rotation=85, fontsize = 11,)
sns.despine()
